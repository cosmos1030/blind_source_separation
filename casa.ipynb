# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

samplerate, data = wavfile.read('MiniLibriMix/train/mix_clean/14-212-0013_7926-254949-0054.wav')

# 스테레오인 경우 첫 번째 채널만 사용
if data.ndim > 1:
    data = data[:, 0]

# 시간 축 생성
time = np.arange(len(data)) / samplerate

# 파형 시각화
plt.figure()
plt.plot(time, data)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Waveform of Loaded Audio')
plt.show()

# 정보 출력
print(f"Sample rate: {samplerate} Hz, Duration: {len(data)/samplerate:.2f} seconds")
# Out:
# Sample rate: 8000 Hz, Duration: 7.57 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

samplerate, data = wavfile.read('MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav')

# 스테레오인 경우 첫 번째 채널만 사용
if data.ndim > 1:
    data = data[:, 0]

# 시간 축 생성
time = np.arange(len(data)) / samplerate

# 파형 시각화
plt.figure()
plt.plot(time, data)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Waveform of Loaded Audio')
plt.show()

# 정보 출력
print(f"Sample rate: {samplerate} Hz, Duration: {len(data)/samplerate:.2f} seconds")
# Out:
# Sample rate: 8000 Hz, Duration: 7.57 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 오디오 파일 불러오기
y, sr = librosa.load("MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav", sr=None)  # sr=None이면 원본 샘플링 유지

# FFT 적용 (양의 주파수 성분만)
Y = np.fft.rfft(y)
freqs = np.fft.rfftfreq(len(y), 1/sr)

# 스펙트럼 시각화 (크기만 볼 거면 abs)
plt.figure(figsize=(12, 4))
plt.plot(freqs, np.abs(Y))
plt.title('Frequency Domain (Magnitude Spectrum)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 오디오 파일 불러오기
y, sr = librosa.load("MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav", sr=None)

# 1~2초 구간 선택
start_sample = int(1 * sr)
end_sample = int(2 * sr)
y_segment = y[start_sample:end_sample]

# FFT 적용
Y = np.fft.rfft(y_segment)[:500]
freqs = np.fft.rfftfreq(len(y_segment), 1/sr)[:500]

# 스펙트럼 시각화
plt.figure(figsize=(12, 4))
plt.plot(freqs, np.abs(Y))
plt.title('Frequency Domain (1–2 sec Segment)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

samplerate, data = wavfile.read('MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav')

# 스테레오인 경우 첫 번째 채널만 사용
if data.ndim > 1:
    data = data[:, 0]

# 시간 축 생성
time = np.arange(len(data)) / samplerate

# 파형 시각화
plt.figure()
plt.plot(time, data)
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.title('Waveform of S2 Loaded Audio')
plt.show()

# 정보 출력
print(f"Sample rate: {samplerate} Hz, Duration: {len(data)/samplerate:.2f} seconds")
# Out:
# Sample rate: 8000 Hz, Duration: 7.57 seconds

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 오디오 파일 불러오기
y, sr = librosa.load("MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav", sr=None)  # sr=None이면 원본 샘플링 유지

# FFT 적용 (양의 주파수 성분만)
Y = np.fft.rfft(y)
freqs = np.fft.rfftfreq(len(y), 1/sr)

# 스펙트럼 시각화 (크기만 볼 거면 abs)
plt.figure(figsize=(12, 4))
plt.plot(freqs, np.abs(Y))
plt.title('Frequency Domain (Magnitude Spectrum)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 오디오 파일 불러오기
y, sr = librosa.load("MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav", sr=None)

# 1~2초 구간 선택
start_sample = int(1 * sr)
end_sample = int(2 * sr)
y_segment = y[start_sample:end_sample]

# FFT 적용
Y = np.fft.rfft(y_segment)[:500]
freqs = np.fft.rfftfreq(len(y_segment), 1/sr)[:500]

# 스펙트럼 시각화
plt.figure(figsize=(12, 4))
plt.plot(freqs, np.abs(Y))
plt.title('Frequency Domain (1–2 sec Segment)')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Magnitude')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# 음성 구간 (1~2초) 다시 불러오기
y, sr = librosa.load("MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav", sr=None)
y_seg = y[int(sr * 1):int(sr * 2)]

# F0 추정
f0 = librosa.yin(y_seg, fmin=50, fmax=300, sr=sr)
times = librosa.times_like(f0, sr=sr)

# 시각화
plt.figure(figsize=(10, 3))
plt.plot(times, f0, label="Estimated F0")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("F0 Contour (1–2s segment)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import librosa
import librosa.display
import matplotlib.pyplot as plt

# 음성 구간 (1~2초) 다시 불러오기
y, sr = librosa.load("MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav", sr=None)
y_seg = y[int(sr * 1):int(sr * 2)]

# F0 추정
f0 = librosa.yin(y_seg, fmin=50, fmax=300, sr=sr)
times = librosa.times_like(f0, sr=sr)

# 시각화
plt.figure(figsize=(10, 3))
plt.plot(times, f0, label="Estimated F0")
plt.xlabel("Time (s)")
plt.ylabel("Frequency (Hz)")
plt.title("F0 Contour (1–2s segment)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gammatone filterbank을 위한 gtgram 사용 (pygammatone 패키지 필요: pip install pygammatone)
from gammatone.gtgram import gtgram

# 1) WAV 파일 로드 (librosa 사용)
import librosa
file_path = 'MiniLibriMix/train/mix_clean/14-212-0013_7926-254949-0054.wav'  # 실제 경로로 수정하세요
data, sr = librosa.load(file_path, sr=None, mono=True)

# 2) Gammatone Spectrogram 계산
#    - window_time: 20 ms, hop_time: 10 ms, 128 채널, 최소 주파수 50 Hz
window_time = 0.020
hop_time = 0.010
n_channels = 128
f_min = 50

gt_spec = gtgram(data, sr, window_time, hop_time, n_channels, f_min)

# 3) 결과 형태 및 간단한 시각화
# gt_spec.shape = (n_channels, n_frames)
print("Gammatone spectrogram shape:", gt_spec.shape)

# Spectrogram 시각화
duration = len(data) / sr
times = np.linspace(0, duration, gt_spec.shape[1])
# 대략적인 중심 주파수 벡터 (음향공학식으로 계산할 수도 있음; 여기서는 대략 균일 분포로 가정)
freqs = np.linspace(f_min, sr/2, n_channels)

plt.figure(figsize=(8, 4))
plt.pcolormesh(times, freqs, gt_spec, shading='auto', vmin=0, vmax=0.001)
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.title('Gammatone Spectrogram (128 channels)')
plt.colorbar(label='Energy')
plt.ylim(0, 300)
plt.tight_layout()
plt.show()
# Out:
# Gammatone spectrogram shape: (128, 756)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gammatone filterbank을 위한 gtgram 사용 (pygammatone 패키지 필요: pip install pygammatone)
from gammatone.gtgram import gtgram

# 1) WAV 파일 로드 (librosa 사용)
import librosa
file_path = 'MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav'  # 실제 경로로 수정하세요
data, sr = librosa.load(file_path, sr=None, mono=True)

# 2) Gammatone Spectrogram 계산
#    - window_time: 20 ms, hop_time: 10 ms, 128 채널, 최소 주파수 50 Hz
window_time = 0.020
hop_time = 0.010
n_channels = 128
f_min = 50

gt_spec = gtgram(data, sr, window_time, hop_time, n_channels, f_min)

# 3) 결과 형태 및 간단한 시각화
# gt_spec.shape = (n_channels, n_frames)
print("Gammatone spectrogram shape:", gt_spec.shape)

# Spectrogram 시각화
duration = len(data) / sr
times = np.linspace(0, duration, gt_spec.shape[1])
# 대략적인 중심 주파수 벡터 (음향공학식으로 계산할 수도 있음; 여기서는 대략 균일 분포로 가정)
freqs = np.linspace(f_min, sr/2, n_channels)

plt.figure(figsize=(8, 4))
plt.pcolormesh(times, freqs, gt_spec, shading='auto', vmin=0, vmax=0.001)
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.title('Gammatone Spectrogram (128 channels)')
plt.colorbar(label='Energy')
plt.ylim(0, 300)
plt.tight_layout()
plt.show()
# Out:
# Gammatone spectrogram shape: (128, 756)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Gammatone filterbank을 위한 gtgram 사용 (pygammatone 패키지 필요: pip install pygammatone)
from gammatone.gtgram import gtgram

# 1) WAV 파일 로드 (librosa 사용)
import librosa
file_path = 'MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav'  # 실제 경로로 수정하세요
data, sr = librosa.load(file_path, sr=None, mono=True)

# 2) Gammatone Spectrogram 계산
#    - window_time: 20 ms, hop_time: 10 ms, 128 채널, 최소 주파수 50 Hz
window_time = 0.020
hop_time = 0.010
n_channels = 128
f_min = 50

gt_spec = gtgram(data, sr, window_time, hop_time, n_channels, f_min)

# 3) 결과 형태 및 간단한 시각화
# gt_spec.shape = (n_channels, n_frames)
print("Gammatone spectrogram shape:", gt_spec.shape)

# Spectrogram 시각화
duration = len(data) / sr
times = np.linspace(0, duration, gt_spec.shape[1])
# 대략적인 중심 주파수 벡터 (음향공학식으로 계산할 수도 있음; 여기서는 대략 균일 분포로 가정)
freqs = np.linspace(f_min, sr/2, n_channels)

plt.figure(figsize=(8, 4))
plt.pcolormesh(times, freqs, gt_spec, shading='auto', vmin=0, vmax=0.01)
plt.xlabel('Time [s]')
plt.ylabel('Frequency [Hz]')
plt.title('Gammatone Spectrogram (128 channels)')
plt.colorbar(label='Energy')
plt.ylim(0, 300)
plt.tight_layout()
plt.show()
# Out:
# Gammatone spectrogram shape: (128, 756)

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 1. 오디오 로드
file_path = 'MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav'
data, sr = librosa.load(file_path, sr=None, mono=True)

# 2. STFT 스펙트로그램 계산
n_fft = 512                     # FFT 창 크기 (~64ms at 8kHz)
hop_length = int(0.010 * sr)   # 10ms hop
win_length = int(0.020 * sr)   # 20ms window

D = librosa.stft(data, n_fft=n_fft, hop_length=hop_length, win_length=win_length)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)  # dB로 변환

# 3. 시각화
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram (STFT, dB scale)')
plt.ylim(0, 300)  # 원하는 주파수 대역 (0~300Hz)로 제한
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# 1. 오디오 로드
file_path = 'MiniLibriMix/train/s2/14-212-0013_7926-254949-0054.wav'
data, sr = librosa.load(file_path, sr=None, mono=True)

# 2. STFT 스펙트로그램 계산
n_fft = 512*2                     # FFT 창 크기 (~64ms at 8kHz)
hop_length = int(0.010 * sr)   # 10ms hop
win_length = int(0.020 * sr)   # 20ms window

D = librosa.stft(data, n_fft=n_fft, hop_length=hop_length, win_length=win_length)
S_db = librosa.amplitude_to_db(np.abs(D), ref=np.max)  # dB로 변환

# 3. 시각화
plt.figure(figsize=(10, 4))
librosa.display.specshow(S_db, sr=sr, x_axis='time', y_axis='hz', hop_length=hop_length)
plt.colorbar(format='%+2.0f dB')
plt.title('Spectrogram (STFT, dB scale)')
plt.ylim(0, 300)  # 원하는 주파수 대역 (0~300Hz)로 제한
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import hilbert

# gt_spec: (128, n_frames) 형태의 Gammatone spectrogram (각 칼럼이 한 프레임)
# 시간-밴드 단위의 신호 재구성(간단히 inverse gammatone은 생략)
# 하지만 envelope 단계만 시뮬레이션한다고 가정합니다.

# 예시로 0번 밴드(envelope)를 꺼내서
band_signal = gt_spec[0, :]

# 1) Half-wave rectification
rectified = np.maximum(band_signal, 0)

# 2) Hilbert envelope
analytic = hilbert(rectified)
envelope = np.abs(analytic)

# 시각화
times = np.linspace(0, len(band_signal)/sr, len(band_signal))
plt.figure()
plt.plot(times, rectified, label='Half-wave rectified')
plt.plot(times, envelope,  label='Envelope (Hilbert)')
plt.legend()
plt.xlabel('Time [s]')
plt.title('Hair-cell Transduction – Band 0')
plt.show()

# %%
import numpy as np
import soundfile as sf
from gammatone.filters import make_erb_filters, erb_filterbank, centre_freqs  # centre_freqs 추가
from scipy.signal import hilbert
import matplotlib.pyplot as plt

# 1) 오디오 로드
audio, sr = sf.read("MiniLibriMix/train/s1/14-212-0013_7926-254949-0054.wav")

# 2) 128채널 ERB 중심 주파수 생성 (50Hz–Nyquist)
n_channels = 128
cfs = centre_freqs(sr, n_channels, 50, sr/2)  # positional args: sr, 채널 수, 시작 주파수, 끝 주파수

# 3) ERB 필터뱅크 계수 생성 (fs, 중심주파수 리스트)
erb_filters = make_erb_filters(sr, cfs)

# 4) 필터 출력 계산: (128, n_samples)
band_signals = erb_filterbank(audio, erb_filters)
print("band_signals shape:", band_signals.shape)  
# → (128, 60560) 이 나와야 합니다.

# 5) 0번 밴드 절반파 정류 + 엔벨롭
band0     = band_signals[0]
rectified = np.maximum(band0, 0)
envelope  = np.abs(hilbert(rectified))

# 6) 시각화
times = np.arange(len(band0)) / sr
plt.figure(figsize=(8,3))
plt.plot(times, rectified, label='Half-wave rectified')
plt.plot(times, envelope,  label='Envelope', alpha=0.7)
plt.xlabel('Time [s]')
plt.title('Band 0 Transduction')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# band_signals shape: (128, 60560)

# %%
gt_spec.shape
# Out:
# (128, 756)

# %%
import numpy as np
from scipy.signal import hilbert

# gt_spec: (n_channels, n_frames) 형태의 Gammatone spectrogram이 주어졌다고 가정

# 1. Half-wave rectification (음의 값을 0으로 잘라냄)
#    → 사람 귀의 외유모세포 반응을 모사
rectified = np.maximum(gt_spec, 0)  # shape: (128, T)
print(rectified.shape)

# 2. Hilbert transform을 통해 envelope 추출
#    → 각 밴드별 진폭의 윤곽선을 구함
analytic = hilbert(rectified, axis=1)  # 복소수 analytic signal
envelopes = np.abs(analytic)           # 진폭 envelope. shape: (128, T)

# 결과:
# envelopes[i, :]는 i번째 주파수 밴드의 시간에 따른 envelope입니다.
# Out:
# (128, 756)

# %%
import numpy as np
from scipy.signal import hilbert, firwin, lfilter

# --- (이전까지의 envelopes 계산) ---
# rectified = np.maximum(gt_spec, 0)
# analytic  = hilbert(rectified, axis=1)
# envelopes = np.abs(analytic)           # shape: (128, T)

# 3) LPF + Kaiser 윈도우 설계
sr = 8000  # 예시: 실제 sr 값으로 바꿔주세요
cutoff = 1000.0  # 1 kHz
win_duration = 0.01825  # 18.25 ms

# 필터 탭 수 (샘플 수) 계산
numtaps = int(np.ceil(win_duration * sr))
# FIR 필터는 홀수 길이 권장
if numtaps % 2 == 0:
    numtaps += 1

# Kaiser 파라미터 (beta): 5 정도가 무난
beta = 5.0

# FIR 저역통과 필터 계수 생성
lpf_coeffs = firwin(
    numtaps,
    cutoff=cutoff,
    window=('kaiser', beta),
    fs=sr
)

# 4) 각 밴드(envelope)에 필터 적용
#    axis=1 로 각 채널의 time축 방향으로 lfilter 실행
envelopes_lpf = lfilter(lpf_coeffs, [1.0], envelopes, axis=1)

# 결과 형태 확인
print("Original envelopes shape:", envelopes.shape)
print("Filtered envelopes shape:", envelopes_lpf.shape)
# Out:
# Original envelopes shape: (128, 756)
# Filtered envelopes shape: (128, 756)

# %%
import numpy as np
import matplotlib.pyplot as plt

# 예시 데이터: envelopes_lpf (n_channels, T), sr (샘플링 레이트)
# 실제 구현에서는 앞 단계에서 얻은 envelopes_lpf과 sr을 사용하세요.
# 여기서는 envelopes_lpf를 임의로 생성해서 예시를 보여드립니다.
n_channels = 128
T = 10000  # 예시 프레임 수
sr = 8000
envelopes_lpf = np.random.rand(n_channels, T)  # 예시 데이터

# 피치 추정 범위 설정 (Hz)
min_f0 = 50
max_f0 = 500

# 대응하는 lag 범위 (샘플 단위)
min_lag = int(sr / max_f0)
max_lag = int(sr / min_f0)
lags = np.arange(min_lag, max_lag + 1)

# 1) 각 채널별 autocorrelation 계산
auto_per_channel = []
for ch in range(n_channels):
    env = envelopes_lpf[ch]
    corr_full = np.correlate(env, env, mode='full')
    corr = corr_full[corr_full.size // 2:]  # 양의 lag만
    auto_per_channel.append(corr[lags])

auto_per_channel = np.array(auto_per_channel)  # shape: (n_channels, len(lags))

# 2) 요약 correlogram: 채널 합산
summary_correlogram = np.sum(auto_per_channel, axis=0)

# 3) 전역 피치 (global pitch) 추출: 최대 피크 지점
peak_idx = np.argmax(summary_correlogram)
pitch_lag = lags[peak_idx]
global_f0 = sr / pitch_lag

# 4) 시각화
plt.figure(figsize=(12, 5))

# (a) 일부 채널들의 autocorrelogram
plt.subplot(1, 2, 1)
for ch in [0, n_channels//2, n_channels-1]:
    plt.plot(lags, auto_per_channel[ch], label=f'Channel {ch}')
plt.xlabel('Lag (samples)')
plt.ylabel('Autocorrelation')
plt.title('Channel-wise Autocorrelograms')
plt.legend()

# (b) 요약 correlogram과 전역 피치 표시
plt.subplot(1, 2, 2)
plt.plot(lags, summary_correlogram, label='Summary Correlogram', color='black')
plt.axvline(pitch_lag, color='red', linestyle='--', label=f'Global F0 = {global_f0:.1f} Hz')
# X축을 주파수 도메인으로 변환
freqs = sr / lags
plt.xlabel('Lag (samples) / Frequency (Hz)')
plt.title('Summary Correlogram and Global Pitch')
plt.legend()

plt.tight_layout()
plt.show()

# 결과 출력
print(f"Estimated global pitch: {global_f0:.1f} Hz (lag = {pitch_lag} samples)")
# Out:
# Estimated global pitch: 500.0 Hz (lag = 16 samples)

# %%
from tqdm import tqdm
import time

# 예시: 기존 segmentation-merge-classification 파이프라인에 tqdm 추가

# 1) T-F 활성 mask 계산 (setup)
thresh = np.percentile(envelopes_lpf, 75)
mask = envelopes_lpf > thresh

# 2) 채널별 세그먼트 추출
segments = []
seg_id = 0
start_time = time.time()
for c in tqdm(range(n_channels), desc="Segment extraction"):
    m = mask[c].astype(int)
    starts = np.where(np.diff(np.pad(m, (1,0))) == 1)[0]
    ends = np.where(np.diff(np.pad(m, (0,1))) == -1)[0]
    for s, e in zip(starts, ends):
        segments.append({'id':seg_id, 'channel':c, 'start':s, 'end':e})
        seg_id += 1
print(f"Segment extraction time: {time.time() - start_time:.2f}s")

# 3) 세그먼트 병합
adj = defaultdict(list)
for i in tqdm(range(len(segments)), desc="Building adjacency"):
    si = segments[i]
    for j in range(i+1, len(segments)):
        sj = segments[j]
        if abs(si['channel'] - sj['channel']) == 1 and not (si['end'] < sj['start'] or sj['end'] < si['start']):
            adj[i].append(j)
            adj[j].append(i)

merged = []
visited = set()
start_time = time.time()
for i in tqdm(range(len(segments)), desc="Merging segments"):
    if i in visited:
        continue
    stack = [i]
    comp = []
    while stack:
        u = stack.pop()
        if u in visited:
            continue
        visited.add(u)
        comp.append(u)
        for v in adj[u]:
            if v not in visited:
                stack.append(v)
    chans = [segments[k]['channel'] for k in comp]
    starts = [segments[k]['start'] for k in comp]
    ends = [segments[k]['end'] for k in comp]
    merged.append({'ids':comp, 'channels':sorted(set(chans)), 'start':min(starts), 'end':max(ends)})
print(f"Merging time: {time.time() - start_time:.2f}s")

# 4) 분류 단계
foreground, background = [], []
start_time = time.time()
tol = 0.1 * global_f0
for seg in tqdm(merged, desc="Classifying segments"):
    f0s = []
    for k in seg['ids']:
        c = segments[k]['channel']
        best = np.argmax(auto_per_channel[c])
        lag = lags[best]
        f0s.append(sr / lag)
    mean_f0 = np.mean(f0s)
    if abs(mean_f0 - global_f0) <= tol:
        foreground.append(seg)
    else:
        background.append(seg)
print(f"Classification time: {time.time() - start_time:.2f}s")
print(f"Total merged: {len(merged)}, Foreground: {len(foreground)}, Background: {len(background)}")

# %%
import numpy as np
from collections import defaultdict

# --- Assumed available from previous steps ---
# segments: list of dicts with keys 'id', 'channel', 'start', 'end'
# auto_per_channel: (n_channels, n_lags)
# lags: (n_lags,)  # autocorr lag (samples)
# global_f0: scalar  # summary correlogram F0 in Hz
# sr: scalar         # sampling rate in Hz
# n_channels: int    # number of channels

# 1) T-F 활성 mask 계산 (setup)
thresh = np.percentile(envelopes_lpf, 75)
mask = envelopes_lpf > thresh

# 2) 채널별 세그먼트 추출
segments = []
seg_id = 0
start_time = time.time()
for c in tqdm(range(n_channels), desc="Segment extraction"):
    m = mask[c].astype(int)
    starts = np.where(np.diff(np.pad(m, (1,0))) == 1)[0]
    ends = np.where(np.diff(np.pad(m, (0,1))) == -1)[0]
    for s, e in zip(starts, ends):
        segments.append({'id':seg_id, 'channel':c, 'start':s, 'end':e})
        seg_id += 1
print(f"Segment extraction time: {time.time() - start_time:.2f}s")

# 1) Group segments by channel
segments_by_channel = defaultdict(list)
for idx, seg in enumerate(segments):
    segments_by_channel[seg['channel']].append(idx)
for c in segments_by_channel:
    segments_by_channel[c].sort(key=lambda i: segments[i]['start'])

# 2) Build adjacency only between adjacent channels with overlap
adj = defaultdict(list)
for c in range(n_channels - 1):
    list1 = segments_by_channel[c]
    list2 = segments_by_channel[c + 1]
    p2 = 0
    for i1 in list1:
        s1, e1 = segments[i1]['start'], segments[i1]['end']
        # advance p2 past segments in channel c+1 ending before s1
        while p2 < len(list2) and segments[list2[p2]]['end'] < s1:
            p2 += 1
        # from p2, any segment starting ≤ e1 overlaps in time
        q = p2
        while q < len(list2) and segments[list2[q]]['start'] <= e1:
            i2 = list2[q]
            adj[i1].append(i2)
            adj[i2].append(i1)
            q += 1

# 3) Merge segments via connected components (DFS)
visited = set()
merged = []
for i in range(len(segments)):
    if i in visited:
        continue
    stack = [i]
    comp = []
    while stack:
        u = stack.pop()
        if u in visited:
            continue
        visited.add(u)
        comp.append(u)
        for v in adj[u]:
            if v not in visited:
                stack.append(v)
    # combine comp
    chans = [segments[k]['channel'] for k in comp]
    starts = [segments[k]['start'] for k in comp]
    ends = [segments[k]['end'] for k in comp]
    merged.append({
        'ids': comp,
        'channels': sorted(set(chans)),
        'start': min(starts),
        'end': max(ends)
    })

# 4) Precompute channel-wise best-lag & f0
best_lag_idx = np.argmax(auto_per_channel, axis=1)
f0_best = sr / lags[best_lag_idx]  # shape (n_channels,)

# 5) Classify merged segments using mean f0 comparison
tol = 0.1 * global_f0  # ±10%
foreground, background = [], []
for seg in merged:
    chans = seg['channels']
    mean_f0 = f0_best[chans].mean()
    if abs(mean_f0 - global_f0) <= tol:
        foreground.append(seg)
    else:
        background.append(seg)

print(f"Total merged segments: {len(merged)}")
print(f" → Foreground: {len(foreground)}, Background: {len(background)}")
# Out:
# Total merged segments: 165600
#  → Foreground: 15540, Background: 150060

# %% [markdown]
# ## Pitch Tracking

# %%
import numpy as np

# --- 앞단계에서 계산된 변수들 ---
# envelopes_lpf: (n_channels, T)
# auto_per_channel: (n_channels, n_lags)
# lags: (n_lags,)  # autocorr lag (samples)
# global_f0: scalar  # summary correlogram에서 뽑은 전역 피치(Hz)
# sr: scalar         # 샘플링 레이트
# foreground: list of segments from initial segregation

n_channels, T = envelopes_lpf.shape

# 1) Foreground mask: 어떤 채널·프레임이 foreground에 속하는지 표시
fg_mask = np.zeros((n_channels, T), dtype=bool)
for seg in foreground:
    chs = seg['channels']
    s, e = seg['start'], seg['end']
    fg_mask[chs, s:e+1] = True

# 2) Frame-by-frame raw pitch period estimation
#    plausible lag 범위 (2ms ~ 12.5ms)
min_lag = int(0.002 * sr)
max_lag = int(0.0125 * sr)
plausible = (lags >= min_lag) & (lags <= max_lag)
lags_pl = lags[plausible]

raw_period = np.full(T, np.nan)
for j in range(T):
    chs = np.where(fg_mask[:, j])[0]
    if chs.size == 0:
        continue
    # 채널별 autocorr 합산
    summary = auto_per_channel[chs][:, plausible].sum(axis=0)
    best = np.argmax(summary)
    raw_period[j] = lags_pl[best] / sr  # 초 단위

# 3) Constraint 1: 단위 유닛 동의율 검사 (θd=0.95)
theta_d = 0.95
reliable = np.zeros(T, dtype=bool)
for j in range(T):
    if np.isnan(raw_period[j]):
        continue
    tau_j = raw_period[j] * sr  # 샘플 단위 lag
    chs = np.where(fg_mask[:, j])[0]
    agree = 0
    for i in chs:
        Ai = auto_per_channel[i]
        # τ(j) 인덱스
        idx_j = np.argmin(np.abs(lags - tau_j))
        # τ_m (채널별 최대 피크) 인덱스
        idx_m = np.argmax(Ai[plausible])
        if Ai[idx_j] / Ai[plausible][idx_m] > theta_d:
            agree += 1
    if agree > (chs.size / 2):
        reliable[j] = True

# 4) Constraint 2: 시간적 연속성 (연속 프레임 간 20% 이내)
for j in range(1, T):
    if reliable[j] and reliable[j-1]:
        if abs(raw_period[j] - raw_period[j-1]) > 0.2 * raw_period[j-1]:
            reliable[j] = False

# 5) 불신뢰 프레임 보정 (forward-fill)
tracked = raw_period.copy()
for j in range(T):
    if not reliable[j] and j>0:
        tracked[j] = tracked[j-1]

# 6) Hz 단위로 변환
f0_tracked = 1.0 / tracked  # NaN은 그대로 NaN

# --- 결과 시각화 (선택) ---
import matplotlib.pyplot as plt

times = np.arange(T) * (hop_time := 0.010)  # hop_time = 10ms
plt.figure(figsize=(10,4))
plt.plot(times, 1.0/raw_period,    label='Raw F0',    alpha=0.6)
plt.plot(times, f0_tracked,         label='Tracked F0', color='red', linewidth=1.5)
plt.scatter(times[~reliable], 1.0/raw_period[~reliable],
            c='gray', marker='x', label='Unreliable')
plt.xlabel('Time (s)')
plt.ylabel('Frequency (Hz)')
plt.title('Pitch Tracking on Foreground Stream')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ##  Unit Labeling (Periodicity & AM criterion)

# %%
import numpy as np
from scipy.signal import firwin, lfilter, hilbert
import matplotlib.pyplot as plt

# --- Assumed available from previous steps ---
# band_signals: (n_channels, n_samples) - raw gammatone filter outputs
# raw_period:    (T,)                  - raw pitch period per frame (seconds)
# f0_tracked:    (T,)                  - tracked pitch (Hz) per frame
# auto_per_channel: (n_channels, n_lags) - autocorrelation per channel
# lags:          (n_lags,)             - autocorr lag values (samples)
# fg_mask:       (n_channels, T)        - mask of resolved units
# hop_length:    int                    - frame hop in samples (e.g. int(0.010 * sr))
# frame_length:  int                    - frame length in samples (e.g. int(0.020 * sr))
# sr:            int                    - sampling rate in Hz
# theta_d:       float                  - periodicity threshold (0.95)
# theta_f:       float                  - AM criterion threshold (0.12)
frame_length = int(0.020 * sr)
theta_f = 0.12

n_channels, n_samples = band_signals.shape
_, T = fg_mask.shape

# Precompute plausible lag indices (2ms – 12.5ms)
min_lag = int(0.002 * sr)
max_lag = int(0.0125 * sr)
plausible_idxs = np.where((lags >= min_lag) & (lags <= max_lag))[0]

unit_label = np.zeros((n_channels, T), dtype=bool)

for i in range(n_channels):
    Ai = auto_per_channel[i]
    # channel-specific peak for periodicity criterion
    tau_m_idx = plausible_idxs[np.argmax(Ai[plausible_idxs])]
    
    for j in range(T):
        # Skip if no pitch estimate
        if np.isnan(raw_period[j]):
            continue
        lag_j = int(round(raw_period[j] * sr))
        
        # 1) Periodicity Criterion for resolved harmonics
        if fg_mask[i, j]:
            if min_lag <= lag_j <= max_lag:
                if Ai[lag_j] / Ai[tau_m_idx] > theta_d:
                    unit_label[i, j] = True
            continue
        
        # 2) AM Criterion for unresolved harmonics
        start = j * hop_length
        end = start + frame_length
        if end > n_samples:
            continue
        x = band_signals[i, start:end]
        
        # a) Half-wave rectification
        x_rect = np.maximum(x, 0)
        
        # b) Band-pass filter around tracked pitch
        f_center = f0_tracked[j]
        if np.isnan(f_center):
            continue
        fmin_bp = max(80, 0.8 * f_center)
        fmax_bp = min(sr/2 - 1, 1.2 * f_center)
        numtaps = 101
        bp_coefs = firwin(numtaps, [fmin_bp, fmax_bp], pass_zero=False, fs=sr)
        x_bp = lfilter(bp_coefs, [1.0], x_rect)
        
        # c) Normalize by envelope to remove amplitude modulation
        env_bp = np.abs(hilbert(x_bp))
        rhat = x_bp / (env_bp + 1e-8)
        
        # d) Sinusoid fitting (grid search over plausible F0 range)
        t = np.arange(len(rhat)) / sr
        f_search = np.linspace(80, 500, 421)
        errors = np.array([np.mean((rhat - np.sin(2*np.pi*f*t))**2) for f in f_search])
        idx_best = np.argmin(errors)
        f_ij = f_search[idx_best]
        min_mse = errors[idx_best]
        energy = np.mean(rhat**2)
        
        # e) Apply AM Criterion
        if (min_mse < 0.5 * energy) and (abs(f_ij * raw_period[j] - 1) < theta_f):
            unit_label[i, j] = True

# `unit_label` is a boolean mask of shape (n_channels, T):
# True indicates the T-F unit is labeled as target speech.
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[48], line 66
#      64 numtaps = 101
#      65 bp_coefs = firwin(numtaps, [fmin_bp, fmax_bp], pass_zero=False, fs=sr)
# ---> 66 x_bp = lfilter(bp_coefs, [1.0], x_rect)
#      68 # c) Normalize by envelope to remove amplitude modulation
#      69 env_bp = np.abs(hilbert(x_bp))
#
# File ~/miniconda3/envs/bss/lib/python3.10/site-packages/scipy/signal/_signaltools.py:2158, in lfilter(b, a, x, axis, zi)
#    2155 b /= a[0]
#    2156 x = np.asarray(x, dtype=dtype)
# -> 2158 out_full = np.apply_along_axis(lambda y: np.convolve(b, y), axis, x)
#    2159 ind = out_full.ndim * [slice(None)]
#    2160 if zi is not None:
#
# File ~/miniconda3/envs/bss/lib/python3.10/site-packages/numpy/lib/_shape_base_impl.py:376, in apply_along_axis(func1d, axis, arr, *args, **kwargs)
#     372 inarr_view = transpose(arr, in_dims[:axis] + in_dims[axis+1:] + [axis])
#     374 # compute indices for the iteration axes, and append a trailing ellipsis to
#     375 # prevent 0d arrays decaying to scalars, which fixes gh-8642
# --> 376 inds = ndindex(inarr_view.shape[:-1])
#     377 inds = (ind + (Ellipsis,) for ind in inds)
#     379 # invoke the function on the first item
#
# File ~/miniconda3/envs/bss/lib/python3.10/site-packages/numpy/lib/_index_tricks_impl.py:695, in ndindex.__init__(self, *shape)
#     692     shape = shape[0]
#     693 x = as_strided(_nx.zeros(1), shape=shape,
#     694                strides=_nx.zeros_like(shape))
# --> 695 self._it = _nx.nditer(x, flags=['multi_index', 'zerosize_ok'],
#     696                       order='C')
#
# KeyboardInterrupt:

# %%
from tqdm import tqdm
import numpy as np
from scipy.signal import firwin, lfilter, hilbert

# Assumed variables from previous steps:
# band_signals, raw_period, f0_tracked, auto_per_channel,
# lags, fg_mask, hop_length, frame_length, sr, theta_d, theta_f
frame_length = int(0.020 * sr)
theta_f = 0.12
n_channels, n_samples = band_signals.shape
_, T = fg_mask.shape

# Precompute plausible lag indices once
min_lag = int(0.002 * sr)
max_lag = int(0.0125 * sr)
plausible_idxs = np.where((lags >= min_lag) & (lags <= max_lag))[0]

# Pre-generate sine table for grid search (speeds up inner loop)
f_search = np.linspace(80, 500, 421)
t_vec = np.arange(frame_length) / sr
sin_table = np.sin(2 * np.pi * np.outer(f_search, t_vec))  # shape: (421, frame_length)

unit_label = np.zeros((n_channels, T), dtype=bool)

# Wrap outer loop with tqdm for progress visualization
for i in tqdm(range(n_channels), desc="Channels"):
    Ai = auto_per_channel[i]
    tau_m_idx = plausible_idxs[np.argmax(Ai[plausible_idxs])]
    
    # Inner loop also with tqdm, disabled leave to reduce clutter
    for j in tqdm(range(T), desc="Frames", leave=False):
        if np.isnan(raw_period[j]):
            continue
        lag_j = int(round(raw_period[j] * sr))
        
        # Periodicity Criterion
        if fg_mask[i, j]:
            if min_lag <= lag_j <= max_lag and Ai[lag_j] / Ai[tau_m_idx] > theta_d:
                unit_label[i, j] = True
            continue
        
        # AM Criterion
        start = j * hop_length
        end = start + frame_length
        if end > n_samples:
            continue
        x = band_signals[i, start:end]
        x_rect = np.maximum(x, 0)
        
        f_center = f0_tracked[j]
        if np.isnan(f_center):
            continue
        fmin_bp = max(80, 0.8 * f_center)
        fmax_bp = min(sr/2 - 1, 1.2 * f_center)
        bp_coefs = firwin(101, [fmin_bp, fmax_bp], pass_zero=False, fs=sr)
        x_bp = lfilter(bp_coefs, [1.0], x_rect)
        
        env_bp = np.abs(hilbert(x_bp))
        rhat = x_bp / (env_bp + 1e-8)
        
        # Compute grid search errors using precomputed sine table
        errors = np.mean((rhat - sin_table)**2, axis=1)
        idx_best = np.argmin(errors)
        f_ij = f_search[idx_best]
        min_mse = errors[idx_best]
        energy = np.mean(rhat**2)
        
        if (min_mse < 0.5 * energy) and (abs(f_ij * raw_period[j] - 1) < theta_f):
            unit_label[i, j] = True

# unit_label now contains the labeled mask
# Out:
# Channels: 100%|██████████| 128/128 [01:21<00:00,  1.56it/s]

# %%
import numpy as np
import soundfile as sf

# --- Assumed available from previous steps ---
# band_signals: (n_channels, n_samples) - raw gammatone filter outputs
# unit_label:   (n_channels, T)          - final T-F unit mask from Unit Labeling
# hop_length:   int                      - frame hop in samples (e.g. int(0.010 * sr))
# frame_length: int                      - frame length in samples (e.g. int(0.020 * sr))
# sr:           int                      - sampling rate in Hz

n_channels, n_samples = band_signals.shape
_, T = unit_label.shape

# 1) Create a sample-level mask for each band
band_mask = np.zeros_like(band_signals)

for i in range(n_channels):
    for j in range(T):
        if unit_label[i, j]:
            start = j * hop_length
            end = start + frame_length
            if end > n_samples:
                end = n_samples
            band_mask[i, start:end] = 1

# 2) Apply mask to band_signals and sum across channels
masked_bands = band_signals * band_mask
resynth = masked_bands.sum(axis=0)

# 3) Normalize output to [-1, 1]
resynth = resynth / np.max(np.abs(resynth))

# 4) Save as WAV
output_path = 'resynthesized_target.wav'
sf.write(output_path, resynth, sr)

print(f"Resynthesized waveform saved to {output_path}")
# Out:
# Resynthesized waveform saved to resynthesized_target.wav
